# %% [markdown]
# <h1>Perceptron</h1>

# %%
import matplotlib.pyplot as plt 
import pandas as pd

# %%
dataset=pd.read_csv(r"C:\Users\wwrao\Downloads\perceptron_classification_data.csv")

# %%
dataset
# Out:
#    Hours Studied  Hours Slept  Passed (1 = Yes, 0 = No)
# 0              2            7                         0
# 1              3            6                         0
# 2              4            6                         1
# 3              5            5                         1
# 4              6            6                         1
# 5              7            8                         1
# 6              8            7                         1
# 7              1            4                         0

# %%
dataset.shape
# Out:
# (8, 3)

# %%
import seaborn as sns 
sns.pairplot(dataset)
# Out:
# C:\Users\wwrao\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\wwrao\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\wwrao\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
x=dataset.iloc[:,0:2]
x=np.array(x)
x
# Out:
# array([[2, 7],
#        [3, 6],
#        [4, 6],
#        [5, 5],
#        [6, 6],
#        [7, 8],
#        [8, 7],
#        [1, 4]], dtype=int64)

# %%
y=dataset.iloc[:,-1]
y=np.array(y)
y
# Out:
# array([0, 0, 1, 1, 1, 1, 1, 0], dtype=int64)

# %% [markdown]
# <h1>Applying Perceptron from sklearn</h1>

# %%
from sklearn.linear_model import Perceeptron
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[147], line 1
# ----> 1 from sklearn.linear_model import Perceeptron
#
# ImportError: cannot import name 'Perceeptron' from 'sklearn.linear_model' (C:\Users\wwrao\anaconda3\Lib\site-packages\sklearn\linear_model\__init__.py)

# %%
l=Perceptron()

# %%
l.fit(x,y)
# Out:
# Perceptron()

# %% [markdown]
# **Coefficient**

# %%
l.coef_
# Out:
# array([[17., -6.]])

# %% [markdown]
# **Biased or Intercept**

# %%
l.intercept_
# Out:
# array([-2.])

# %%
from mlxtend.plotting import  plot_decision_regions
import numpy as np

# %%
plot_decision_regions(x,y,clf=l,legend=1)
plt.axis("off")
# Out:
# (0.0, 9.0, 3.0, 9.0)
